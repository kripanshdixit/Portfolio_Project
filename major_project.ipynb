# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import plotly as py
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('glassdoor_jobs.csv')
df
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 954         954                                      Data Engineer
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 951  $72K-$133K (Glassdoor est.)
# 952   $56K-$91K (Glassdoor est.)
# 953  $95K-$160K (Glassdoor est.)
# 954                           -1
# 955  $61K-$126K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1    What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2    KnowBe4, Inc. is a high growth information sec...     4.8
# 3    *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 951  THE CHALLENGE\nEventbrite has a world-class da...     4.4
# 952  The Auton Lab at Carnegie Mellon University is...     2.6
# 953  Data Science ManagerResponsibilities:\n\nOvers...     3.2
# 954  Loading...\n\nTitle: Data Engineer\n\nLocation...     4.8
# 955  Returning Candidate? Log back in to the Career...     3.6
#
#                                    Company Name         Location  \
# 0                        Tecolote Research\n3.8  Albuquerque, NM
# 1    University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                  KnowBe4\n4.8   Clearwater, FL
# 3                                     PNNL\n3.8     Richland, WA
# 4                       Affinity Solutions\n2.9     New York, NY
# ..                                          ...              ...
# 951                             Eventbrite\n4.4    Nashville, TN
# 952         Software Engineering Institute\n2.6   Pittsburgh, PA
# 953                           Numeric, LLC\n3.2    Allentown, PA
# 954                                   IGNW\n4.8       Austin, TX
# 955           Riverside Research Institute\n3.6  Beavercreek, OH
#
#           Headquarters                    Size  Founded  \
# 0           Goleta, CA   501 to 1000 employees     1973
# 1        Baltimore, MD        10000+ employees     1984
# 2       Clearwater, FL   501 to 1000 employees     2010
# 3         Richland, WA  1001 to 5000 employees     1965
# 4         New York, NY     51 to 200 employees     1998
# ..                 ...                     ...      ...
# 951  San Francisco, CA  1001 to 5000 employees     2006
# 952     Pittsburgh, PA   501 to 1000 employees     1984
# 953    Chadds Ford, PA       1 to 50 employees       -1
# 954       Portland, OR    201 to 500 employees     2015
# 955      Arlington, VA   501 to 1000 employees     1967
#
#           Type of ownership                          Industry  \
# 0         Company - Private               Aerospace & Defense
# 1        Other Organization  Health Care Services & Hospitals
# 2         Company - Private                 Security Services
# 3                Government                            Energy
# 4         Company - Private           Advertising & Marketing
# ..                      ...                               ...
# 951        Company - Public                          Internet
# 952    College / University           Colleges & Universities
# 953       Company - Private            Staffing & Outsourcing
# 954       Company - Private                       IT Services
# 955  Nonprofit Organization                  Federal Agencies
#
#                            Sector                           Revenue  \
# 0             Aerospace & Defense         $50 to $100 million (USD)
# 1                     Health Care            $2 to $5 billion (USD)
# 2               Business Services        $100 to $500 million (USD)
# 3    Oil, Gas, Energy & Utilities  $500 million to $1 billion (USD)
# 4               Business Services          Unknown / Non-Applicable
# ..                            ...                               ...
# 951        Information Technology        $100 to $500 million (USD)
# 952                     Education          Unknown / Non-Applicable
# 953             Business Services           $5 to $10 million (USD)
# 954        Information Technology          $25 to $50 million (USD)
# 955                    Government         $50 to $100 million (USD)
#
#                                            Competitors
# 0                                                   -1
# 1                                                   -1
# 2                                                   -1
# 3    Oak Ridge National Laboratory, National Renewa...
# 4                 Commerce Signals, Cardlytics, Yodlee
# ..                                                 ...
# 951                    See Tickets, TicketWeb, Vendini
# 952                                                 -1
# 953                                                 -1
# 954                                             Slalom
# 955                                                 -1
#
# [956 rows x 15 columns]

# %%
df.head()
# Out:
#    Unnamed: 0                  Job Title              Salary Estimate  \
# 0           0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
#
#      Headquarters                    Size  Founded   Type of ownership  \
# 0      Goleta, CA   501 to 1000 employees     1973   Company - Private
# 1   Baltimore, MD        10000+ employees     1984  Other Organization
# 2  Clearwater, FL   501 to 1000 employees     2010   Company - Private
# 3    Richland, WA  1001 to 5000 employees     1965          Government
# 4    New York, NY     51 to 200 employees     1998   Company - Private
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                 Security Services             Business Services
# 3                            Energy  Oil, Gas, Energy & Utilities
# 4           Advertising & Marketing             Business Services
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2        $100 to $500 million (USD)
# 3  $500 million to $1 billion (USD)
# 4          Unknown / Non-Applicable
#
#                                          Competitors
# 0                                                 -1
# 1                                                 -1
# 2                                                 -1
# 3  Oak Ridge National Laboratory, National Renewa...
# 4               Commerce Signals, Cardlytics, Yodlee

# %%
df.tail()
# Out:
#      Unnamed: 0                                          Job Title  \
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 954         954                                      Data Engineer
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 951  $72K-$133K (Glassdoor est.)
# 952   $56K-$91K (Glassdoor est.)
# 953  $95K-$160K (Glassdoor est.)
# 954                           -1
# 955  $61K-$126K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 951  THE CHALLENGE\nEventbrite has a world-class da...     4.4
# 952  The Auton Lab at Carnegie Mellon University is...     2.6
# 953  Data Science ManagerResponsibilities:\n\nOvers...     3.2
# 954  Loading...\n\nTitle: Data Engineer\n\nLocation...     4.8
# 955  Returning Candidate? Log back in to the Career...     3.6
#
#                             Company Name         Location       Headquarters  \
# 951                      Eventbrite\n4.4    Nashville, TN  San Francisco, CA
# 952  Software Engineering Institute\n2.6   Pittsburgh, PA     Pittsburgh, PA
# 953                    Numeric, LLC\n3.2    Allentown, PA    Chadds Ford, PA
# 954                            IGNW\n4.8       Austin, TX       Portland, OR
# 955    Riverside Research Institute\n3.6  Beavercreek, OH      Arlington, VA
#
#                        Size  Founded       Type of ownership  \
# 951  1001 to 5000 employees     2006        Company - Public
# 952   501 to 1000 employees     1984    College / University
# 953       1 to 50 employees       -1       Company - Private
# 954    201 to 500 employees     2015       Company - Private
# 955   501 to 1000 employees     1967  Nonprofit Organization
#
#                     Industry                  Sector  \
# 951                 Internet  Information Technology
# 952  Colleges & Universities               Education
# 953   Staffing & Outsourcing       Business Services
# 954              IT Services  Information Technology
# 955         Federal Agencies              Government
#
#                         Revenue                      Competitors
# 951  $100 to $500 million (USD)  See Tickets, TicketWeb, Vendini
# 952    Unknown / Non-Applicable                               -1
# 953     $5 to $10 million (USD)                               -1
# 954    $25 to $50 million (USD)                           Slalom
# 955   $50 to $100 million (USD)                               -1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         956 non-null    int64
#  1   Job Title          956 non-null    object
#  2   Salary Estimate    956 non-null    object
#  3   Job Description    956 non-null    object
#  4   Rating             956 non-null    float64
#  5   Company Name       956 non-null    object
#  6   Location           956 non-null    object
#  7   Headquarters       956 non-null    object
#  8   Size               956 non-null    object
#  9   Founded            956 non-null    int64
#  10  Type of ownership  956 non-null    object
#  11  Industry           956 non-null    object
#  12  Sector             956 non-null    object
#  13  Revenue            956 non-null    object
#  14  Competitors        956 non-null    object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 112.2+ KB

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 951                               Senior Data Engineer
# 952  Project Scientist - Auton Lab, Robotics Institute
# 953                               Data Science Manager
# 954                                      Data Engineer
# 955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 951  $72K-$133K (Glassdoor est.)
# 952   $56K-$91K (Glassdoor est.)
# 953  $95K-$160K (Glassdoor est.)
# 954                           -1
# 955  $61K-$126K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1    What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2    KnowBe4, Inc. is a high growth information sec...     4.8
# 3    *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 951  THE CHALLENGE\nEventbrite has a world-class da...     4.4
# 952  The Auton Lab at Carnegie Mellon University is...     2.6
# 953  Data Science ManagerResponsibilities:\n\nOvers...     3.2
# 954  Loading...\n\nTitle: Data Engineer\n\nLocation...     4.8
# 955  Returning Candidate? Log back in to the Career...     3.6
#
#                                    Company Name         Location  \
# 0                        Tecolote Research\n3.8  Albuquerque, NM
# 1    University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                  KnowBe4\n4.8   Clearwater, FL
# 3                                     PNNL\n3.8     Richland, WA
# 4                       Affinity Solutions\n2.9     New York, NY
# ..                                          ...              ...
# 951                             Eventbrite\n4.4    Nashville, TN
# 952         Software Engineering Institute\n2.6   Pittsburgh, PA
# 953                           Numeric, LLC\n3.2    Allentown, PA
# 954                                   IGNW\n4.8       Austin, TX
# 955           Riverside Research Institute\n3.6  Beavercreek, OH
#
#           Headquarters                    Size  Founded  \
# 0           Goleta, CA   501 to 1000 employees     1973
# 1        Baltimore, MD        10000+ employees     1984
# 2       Clearwater, FL   501 to 1000 employees     2010
# 3         Richland, WA  1001 to 5000 employees     1965
# 4         New York, NY     51 to 200 employees     1998
# ..                 ...                     ...      ...
# 951  San Francisco, CA  1001 to 5000 employees     2006
# 952     Pittsburgh, PA   501 to 1000 employees     1984
# 953    Chadds Ford, PA       1 to 50 employees       -1
# 954       Portland, OR    201 to 500 employees     2015
# 955      Arlington, VA   501 to 1000 employees     1967
#
#           Type of ownership                          Industry  \
# 0         Company - Private               Aerospace & Defense
# 1        Other Organization  Health Care Services & Hospitals
# 2         Company - Private                 Security Services
# 3                Government                            Energy
# 4         Company - Private           Advertising & Marketing
# ..                      ...                               ...
# 951        Company - Public                          Internet
# 952    College / University           Colleges & Universities
# 953       Company - Private            Staffing & Outsourcing
# 954       Company - Private                       IT Services
# 955  Nonprofit Organization                  Federal Agencies
#
#                            Sector                           Revenue  \
# 0             Aerospace & Defense         $50 to $100 million (USD)
# 1                     Health Care            $2 to $5 billion (USD)
# 2               Business Services        $100 to $500 million (USD)
# 3    Oil, Gas, Energy & Utilities  $500 million to $1 billion (USD)
# 4               Business Services          Unknown / Non-Applicable
# ..                            ...                               ...
# 951        Information Technology        $100 to $500 million (USD)
# 952                     Education          Unknown / Non-Applicable
# 953             Business Services           $5 to $10 million (USD)
# 954        Information Technology          $25 to $50 million (USD)
# 955                    Government         $50 to $100 million (USD)
#
#                                            Competitors
# 0                                                   -1
# 1                                                   -1
# 2                                                   -1
# 3    Oak Ridge National Laboratory, National Renewa...
# 4                 Commerce Signals, Cardlytics, Yodlee
# ..                                                 ...
# 951                    See Tickets, TicketWeb, Vendini
# 952                                                 -1
# 953                                                 -1
# 954                                             Slalom
# 955                                                 -1
#
# [956 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          956 non-null    object
#  1   Salary Estimate    956 non-null    object
#  2   Job Description    956 non-null    object
#  3   Rating             956 non-null    float64
#  4   Company Name       956 non-null    object
#  5   Location           956 non-null    object
#  6   Headquarters       956 non-null    object
#  7   Size               956 non-null    object
#  8   Founded            956 non-null    int64
#  9   Type of ownership  956 non-null    object
#  10  Industry           956 non-null    object
#  11  Sector             956 non-null    object
#  12  Revenue            956 non-null    object
#  13  Competitors        956 non-null    object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 104.7+ KB

# %%
df.loc[:, 'Founded'] = df['Founded'].astype(object)

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors'],
#       dtype='object')

# %%
df. shape
# Out:
# (956, 14)

# %%
df=df.drop_duplicates()
df
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 922                                     Data Scientist
# 925                                    Data Scientists
# 928  Associate Scientist / Sr. Associate Scientist,...
# 945                    Machine Learning Engineer (NLP)
# 948                                      Data Engineer
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 922                           -1
# 925                           -1
# 928  $59K-$125K (Glassdoor est.)
# 945  $80K-$142K (Glassdoor est.)
# 948  $62K-$113K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1    What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2    KnowBe4, Inc. is a high growth information sec...     4.8
# 3    *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 922  Steel Point Solutions is an amazing SBA Certif...     4.7
# 925  Position Description:\nThe Analytics Research ...     3.3
# 928  Who we are\n\n23andMe, the leading consumer ge...     4.0
# 945  CK-12’s mission is to provide free access to o...     4.1
# 948  Do you find data architecture exciting? Does b...     3.9
#
#                                    Company Name                 Location  \
# 0                        Tecolote Research\n3.8          Albuquerque, NM
# 1    University of Maryland Medical System\n3.4            Linthicum, MD
# 2                                  KnowBe4\n4.8           Clearwater, FL
# 3                                     PNNL\n3.8             Richland, WA
# 4                       Affinity Solutions\n2.9             New York, NY
# ..                                          ...                      ...
# 922             Steel Point Solutions, LLC\n4.7           Alexandria, VA
# 925               Miracle Software Systems\n3.3                 Michigan
# 928                                23andMe\n4.0  South San Francisco, CA
# 945                       CK-12 Foundation\n4.1            Palo Alto, CA
# 948                              Fivestars\n3.9        San Francisco, CA
#
#           Headquarters                    Size Founded   Type of ownership  \
# 0           Goleta, CA   501 to 1000 employees    1973   Company - Private
# 1        Baltimore, MD        10000+ employees    1984  Other Organization
# 2       Clearwater, FL   501 to 1000 employees    2010   Company - Private
# 3         Richland, WA  1001 to 5000 employees    1965          Government
# 4         New York, NY     51 to 200 employees    1998   Company - Private
# ..                 ...                     ...     ...                 ...
# 922      Calverton, MD       1 to 50 employees    2013  Other Organization
# 925           Novi, MI     51 to 200 employees    1994   Company - Private
# 928      Sunnyvale, CA   501 to 1000 employees    2006   Company - Private
# 945      Palo Alto, CA       1 to 50 employees    2007   Company - Private
# 948  San Francisco, CA    201 to 500 employees    2011   Company - Private
#
#                                     Industry                        Sector  \
# 0                        Aerospace & Defense           Aerospace & Defense
# 1           Health Care Services & Hospitals                   Health Care
# 2                          Security Services             Business Services
# 3                                     Energy  Oil, Gas, Energy & Utilities
# 4                    Advertising & Marketing             Business Services
# ..                                       ...                           ...
# 922  Enterprise Software & Network Solutions        Information Technology
# 925                              IT Services        Information Technology
# 928                Biotech & Pharmaceuticals     Biotech & Pharmaceuticals
# 945                           K-12 Education                     Education
# 948                                 Internet        Information Technology
#
#                               Revenue  \
# 0           $50 to $100 million (USD)
# 1              $2 to $5 billion (USD)
# 2          $100 to $500 million (USD)
# 3    $500 million to $1 billion (USD)
# 4            Unknown / Non-Applicable
# ..                                ...
# 922          Unknown / Non-Applicable
# 925         $50 to $100 million (USD)
# 928          Unknown / Non-Applicable
# 945          Unknown / Non-Applicable
# 948        $100 to $500 million (USD)
#
#                                            Competitors
# 0                                                   -1
# 1                                                   -1
# 2                                                   -1
# 3    Oak Ridge National Laboratory, National Renewa...
# 4                 Commerce Signals, Cardlytics, Yodlee
# ..                                                 ...
# 922                                                 -1
# 925                                           CSC, IBM
# 928  Ancestry, Verily Life Sciences, Abbott Laborat...
# 945                                                 -1
# 948                                      Belly, SpotOn
#
# [600 rows x 14 columns]

# %%
df.shape
# Out:
# (600, 14)

# %%
print(df.isnull().sum())
# Out:
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# dtype: int64

# %%
df['Sector'].value_counts()
# Out:
# Sector
# Information Technology                164
# Business Services                      97
# Biotech & Pharmaceuticals              82
# Insurance                              43
# Finance                                33
# Health Care                            26
# Aerospace & Defense                    24
# -1                                     24
# Manufacturing                          21
# Education                              16
# Retail                                  9
# Oil, Gas, Energy & Utilities            9
# Non-Profit                              9
# Media                                   8
# Government                              8
# Real Estate                             5
# Travel & Tourism                        5
# Transportation & Logistics              4
# Telecommunications                      3
# Consumer Services                       3
# Mining & Metals                         2
# Construction, Repair & Maintenance      2
# Agriculture & Forestry                  1
# Arts, Entertainment & Recreation        1
# Accounting & Legal                      1
# Name: count, dtype: int64

# %%
df.Location.value_counts()
# Out:
# Location
# New York, NY              49
# San Francisco, CA         48
# Cambridge, MA             34
# Chicago, IL               21
# Boston, MA                14
#                           ..
# Lafayette, LA              1
# Annapolis Junction, MD     1
# Carlsbad, CA               1
# Highland, CA               1
# Michigan                   1
# Name: count, Length: 237, dtype: int64

# %%
df.sort_values(by='Rating',ascending=False)
# Out:
#                                              Job Title  \
# 165                       Scientist, Biomarker Science
# 893                              Senior Data Scientist
# 195  Senior Director Biometrics and Clinical Data M...
# 196                              Senior Data Scientist
# 542                                     Data Scientist
# ..                                                 ...
# 741      Scientist – Cancer Discovery, Molecular Assay
# 583                                     Data Scientist
# 819  Principal Research Scientist/Team Lead, Medici...
# 531                                 Lead Data Engineer
# 618                                     Data Scientist
#
#                           Salary Estimate  \
# 165                                    -1
# 893  Employer Provided Salary:$120K-$140K
# 195                                    -1
# 196                                    -1
# 542           $75K-$127K (Glassdoor est.)
# ..                                    ...
# 741  Employer Provided Salary:$100K-$135K
# 583           $81K-$140K (Glassdoor est.)
# 819  Employer Provided Salary:$120K-$145K
# 531                                    -1
# 618                                    -1
#
#                                        Job Description  Rating  \
# 165  At Alector, our mission is to develop therapie...     5.0
# 893  SkySync is a dynamic, fast-paced, venture-back...     5.0
# 195  At Alector, our mission is to develop therapie...     5.0
# 196  Hamilton Porter is a technical recruiting firm...     5.0
# 542  Title: Data Scientist\n\nLocation: Springfield...     5.0
# ..                                                 ...     ...
# 741  Scientist – Cancer Discovery, Molecular Assay\...    -1.0
# 583  As a Data Scientist, you will play a critical ...    -1.0
# 819  Principal Research Scientist/Team Lead, Medici...    -1.0
# 531  OneThree Biotech is a VC backed startup workin...    -1.0
# 618  This role requires you work closely with a var...    -1.0
#
#                  Company Name                 Location  \
# 165              Alector\n5.0  South San Francisco, CA
# 893              SkySync\n5.0            Ann Arbor, MI
# 195              Alector\n5.0  South San Francisco, CA
# 196  Hamilton Porter LLC\n5.0             Fort Lee, NJ
# 542     Royce Geospatial\n5.0          Springfield, VA
# ..                        ...                      ...
# 741   Monte Rosa Therapeutics            Cambridge, MA
# 583                      ALIN             New York, NY
# 819                Kronos Bio            Cambridge, MA
# 531          OneThree Biotech             New York, NY
# 618                 WeRide.ai             San Jose, CA
#
#                 Headquarters                 Size Founded  Type of ownership  \
# 165  South San Francisco, CA  51 to 200 employees    2013   Company - Public
# 893            Ann Arbor, MI  51 to 200 employees    2011  Company - Private
# 195  South San Francisco, CA  51 to 200 employees    2013   Company - Public
# 196        Newport Beach, CA    1 to 50 employees    2019   Company - Public
# 542            Arlington, VA  51 to 200 employees    2014  Company - Private
# ..                       ...                  ...     ...                ...
# 741                       -1                   -1      -1                 -1
# 583             Noida, India              Unknown      -1  Company - Private
# 819            San Mateo, CA              Unknown      -1  Company - Private
# 531             New York, NY    1 to 50 employees      -1            Unknown
# 618                       -1                   -1      -1                 -1
#
#                          Industry                     Sector  \
# 165     Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 893  Computer Hardware & Software     Information Technology
# 195     Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 196        Staffing & Outsourcing          Business Services
# 542           Aerospace & Defense        Aerospace & Defense
# ..                            ...                        ...
# 741                            -1                         -1
# 583                            -1                         -1
# 819                            -1                         -1
# 531                            -1                         -1
# 618                            -1                         -1
#
#                       Revenue Competitors
# 165  Unknown / Non-Applicable          -1
# 893  Unknown / Non-Applicable          -1
# 195  Unknown / Non-Applicable          -1
# 196  Unknown / Non-Applicable          -1
# 542  $10 to $25 million (USD)          -1
# ..                        ...         ...
# 741                        -1          -1
# 583  Unknown / Non-Applicable          -1
# 819  Unknown / Non-Applicable          -1
# 531  Unknown / Non-Applicable          -1
# 618                        -1          -1
#
# [600 rows x 14 columns]

# %%
df.groupby('Job Title').sum()
# Out:
#                                                                 Salary Estimate  \
# Job Title
# ATL - Data & Analytics (DA)                                                  -1
# AWS Data Engineer                                                            -1
# Advanced Analytics Manager                                                   -1
# Ag Data Scientist                                   $60K-$101K (Glassdoor est.)
# Analytics - Business Assurance Data Analyst          $31K-$55K (Glassdoor est.)
# ...                                                                         ...
# Technology-Minded, Data Professional Opportunities  $40K-$101K (Glassdoor est.)
# UX Data Scientist (Python)                                                   -1
# VP, Data Science                                    $83K-$166K (Glassdoor est.)
# Weapons and Sensors Engineer/Scientist – Entry ...                           -1
# Web Data Analyst                                    $77K-$135K (Glassdoor est.)
#
#                                                                                       Job Description  \
# Job Title
# ATL - Data & Analytics (DA)                         Overview\n\n\nAt a lot of organizations, it is...
# AWS Data Engineer                                   AWS Data Engineer Northern, VA\n\nAWS Data Eng...
# Advanced Analytics Manager                          Job Title: Advanced Analytics Manager or Direc...
# Ag Data Scientist                                   We're leaders. Innovators. Perfectionists. Con...
# Analytics - Business Assurance Data Analyst         Analytics - Business Assurance Data Analyst (C...
# ...                                                                                               ...
# Technology-Minded, Data Professional Opportunities  At VU, we help Veterans buy homes. To make tha...
# UX Data Scientist (Python)                          JOB DESCRIPTION:\nSummary\nAs the Data Scienti...
# VP, Data Science                                    Oversee a team of Data Scientists with overall...
# Weapons and Sensors Engineer/Scientist – Entry ...  Position Description\n\n\nDynetics, a wholly o...
# Web Data Analyst                                    We are looking for a Web Data Analyst to assis...
#
#                                                     Rating  \
# Job Title
# ATL - Data & Analytics (DA)                            4.3
# AWS Data Engineer                                      4.5
# Advanced Analytics Manager                             4.8
# Ag Data Scientist                                      4.6
# Analytics - Business Assurance Data Analyst            4.6
# ...                                                    ...
# Technology-Minded, Data Professional Opportunities     4.7
# UX Data Scientist (Python)                             4.4
# VP, Data Science                                       3.2
# Weapons and Sensors Engineer/Scientist – Entry ...     3.8
# Web Data Analyst                                       4.2
#
#                                                                             Company Name  \
# Job Title
# ATL - Data & Analytics (DA)                            Daugherty Business Solutions\n4.3
# AWS Data Engineer                                                  NuWave Solutions\n4.5
# Advanced Analytics Manager                                             Health Union\n4.8
# Ag Data Scientist                                                    Beck's Hybrids\n4.6
# Analytics - Business Assurance Data Analyst         GreatAmerica Financial Services\n4.6
# ...                                                                                  ...
# Technology-Minded, Data Professional Opportunities       Veterans United Home Loans\n4.7
# UX Data Scientist (Python)                                          OSI Engineering\n4.4
# VP, Data Science                                                           PennyMac\n3.2
# Weapons and Sensors Engineer/Scientist – Entry ...                         Dynetics\n3.8
# Web Data Analyst                                                   Clarity Insights\n4.2
#
#                                                              Location  \
# Job Title
# ATL - Data & Analytics (DA)                               Atlanta, GA
# AWS Data Engineer                                            Virginia
# Advanced Analytics Manager                           Philadelphia, PA
# Ag Data Scientist                                         Atlanta, IN
# Analytics - Business Assurance Data Analyst          Cedar Rapids, IA
# ...                                                               ...
# Technology-Minded, Data Professional Opportunities       Columbia, MO
# UX Data Scientist (Python)                          San Francisco, CA
# VP, Data Science                                          Phoenix, AZ
# Weapons and Sensors Engineer/Scientist – Entry ...     Huntsville, AL
# Web Data Analyst                                         San Jose, CA
#
#                                                             Headquarters  \
# Job Title
# ATL - Data & Analytics (DA)                              Saint Louis, MO
# AWS Data Engineer                                            Mc Lean, VA
# Advanced Analytics Manager                              Philadelphia, PA
# Ag Data Scientist                                            Atlanta, IN
# Analytics - Business Assurance Data Analyst             Cedar Rapids, IA
# ...                                                                  ...
# Technology-Minded, Data Professional Opportunities          Columbia, MO
# UX Data Scientist (Python)                                  Campbell, CA
# VP, Data Science                                    Westlake Village, CA
# Weapons and Sensors Engineer/Scientist – Entry ...        Huntsville, AL
# Web Data Analyst                                             Chicago, IL
#
#                                                                       Size  \
# Job Title
# ATL - Data & Analytics (DA)                         1001 to 5000 employees
# AWS Data Engineer                                      51 to 200 employees
# Advanced Analytics Manager                             51 to 200 employees
# Ag Data Scientist                                    501 to 1000 employees
# Analytics - Business Assurance Data Analyst          501 to 1000 employees
# ...                                                                    ...
# Technology-Minded, Data Professional Opportunities  1001 to 5000 employees
# UX Data Scientist (Python)                             51 to 200 employees
# VP, Data Science                                    1001 to 5000 employees
# Weapons and Sensors Engineer/Scientist – Entry ...  1001 to 5000 employees
# Web Data Analyst                                      201 to 500 employees
#
#                                                    Founded  Type of ownership  \
# Job Title
# ATL - Data & Analytics (DA)                           1985  Company - Private
# AWS Data Engineer                                     1999  Company - Private
# Advanced Analytics Manager                            2009  Company - Private
# Ag Data Scientist                                     1937  Company - Private
# Analytics - Business Assurance Data Analyst           1992  Company - Private
# ...                                                    ...                ...
# Technology-Minded, Data Professional Opportunities    2002  Company - Private
# UX Data Scientist (Python)                            2010  Company - Private
# VP, Data Science                                      2008   Company - Public
# Weapons and Sensors Engineer/Scientist – Entry ...    1974  Company - Private
# Web Data Analyst                                      2008  Company - Private
#
#                                                                   Industry  \
# Job Title
# ATL - Data & Analytics (DA)                                    IT Services
# AWS Data Engineer                                              IT Services
# Advanced Analytics Manager                                      Publishing
# Ag Data Scientist                                    Farm Support Services
# Analytics - Business Assurance Data Analyst                        Lending
# ...                                                                    ...
# Technology-Minded, Data Professional Opportunities                 Lending
# UX Data Scientist (Python)                          Staffing & Outsourcing
# VP, Data Science                                                   Lending
# Weapons and Sensors Engineer/Scientist – Entry ...     Aerospace & Defense
# Web Data Analyst                                               IT Services
#
#                                                                     Sector  \
# Job Title
# ATL - Data & Analytics (DA)                         Information Technology
# AWS Data Engineer                                   Information Technology
# Advanced Analytics Manager                                           Media
# Ag Data Scientist                                   Agriculture & Forestry
# Analytics - Business Assurance Data Analyst                        Finance
# ...                                                                    ...
# Technology-Minded, Data Professional Opportunities                 Finance
# UX Data Scientist (Python)                               Business Services
# VP, Data Science                                                   Finance
# Weapons and Sensors Engineer/Scientist – Entry ...     Aerospace & Defense
# Web Data Analyst                                    Information Technology
#
#                                                                              Revenue  \
# Job Title
# ATL - Data & Analytics (DA)                               $100 to $500 million (USD)
# AWS Data Engineer                                            $5 to $10 million (USD)
# Advanced Analytics Manager                                  Unknown / Non-Applicable
# Ag Data Scientist                                          $50 to $100 million (USD)
# Analytics - Business Assurance Data Analyst               $100 to $500 million (USD)
# ...                                                                              ...
# Technology-Minded, Data Professional Opportunities          Unknown / Non-Applicable
# UX Data Scientist (Python)                                  $25 to $50 million (USD)
# VP, Data Science                                    $500 million to $1 billion (USD)
# Weapons and Sensors Engineer/Scientist – Entry ...        $100 to $500 million (USD)
# Web Data Analyst                                            Unknown / Non-Applicable
#
#                                                                                           Competitors
# Job Title
# ATL - Data & Analytics (DA)                                                                        -1
# AWS Data Engineer                                                                                  -1
# Advanced Analytics Manager                                                                         -1
# Ag Data Scientist                                                                                  -1
# Analytics - Business Assurance Data Analyst                                                        -1
# ...                                                                                               ...
# Technology-Minded, Data Professional Opportunities                                                 -1
# UX Data Scientist (Python)                                                                         -1
# VP, Data Science                                    Nationstar Mortgage, Caliber Funding, Quicken ...
# Weapons and Sensors Engineer/Scientist – Entry ...                                                 -1
# Web Data Analyst                                                                                   -1
#
# [328 rows x 13 columns]
